# %%
# MMPP: Mobile Malaria Project Pipelines
# ----------------------------------------
# Search for the presence of 
# a listed set of non-synonymous mutations
# in a specified gene 
# amongst the reads of a sorted `.bam` file
# ----------------------------------------
# JHendry, 2019/03/27

# %%
import os
import sys
import configparser
import getopt
import numpy as np
import pandas as pd
from collections import Counter
from lib.mutation import *

# %% [markdown]
# ## User Inputs

# %%
input_bam = "data/ont/uk/2019-03-28/BC08.sorted.bam"
gene_ini = "data/resources/pf-regions/kelch13.ini"
min_freq = 0.1
downsample = False

# %%
input_path = os.path.dirname(input_bam)
output_path = input_path.replace("data", "analysis")
if not os.path.isdir(output_path):
    os.mkdir(output_path)

# %%
config = configparser.ConfigParser()
config.read(gene_ini)

# hold gene location information
gene_dt = {}
gene_dt["name"] = config.get("Location", "name")
gene_dt["genome"] = config.get("Location", "genome")
gene_dt["chromosome"] = config.get("Location", "chromosome")
gene_dt["start"] = config.getint("Location", "start")
gene_dt["end"] = config.getint("Location", "end")
gene_dt["strand"] = config.get("Location", "strand")
     
# hold mutation information
mutations = config.get("Mutations", "listed").split(", ")
n_mutations = len(mutations)

# %%
print("================================================================================")
print("MMP Mutation Search Pipeline")
print("--------------------------------------------------------------------------------")
print("Gene:", gene_dt["name"])
print("Chromosome:", gene_dt["chromosome"])
print("Start:", gene_dt["start"])
print("End:", gene_dt["end"])
print("Strand:", gene_dt["strand"])
print("")
print("Searching for %d mutations." % n_mutations)
print("")
print("Input BAM:", input_bam)
print("Output path:", output_path)
print("Reference genome:", gene_dt["genome"])
print("")
print("Downsampling?", downsample)
print("================================================================================")
# Out:
# ================================================================================
# MMP Mutation Search Pipeline
# --------------------------------------------------------------------------------
# Gene: KELCH13
# Chromosome: Pf3D7_13_v3
# Start: 1724817
# End: 1726997
# Strand: reverse
#
# Searching for 31 mutations.
#
# Input BAM: data/ont/uk/2019-03-28/BC08.sorted.bam
# Output path: analysis/ont/uk/2019-03-28
# Reference genome: data/resources/plasmodb/39/PlasmoDB-39_Pfalciparum3D7_Genome.fasta
#
# Downsampling? False
# ================================================================================

# %%
pileup_bam = input_bam

# %%
# Generate read pileup using samtools
pileup_path = pileup_bam.replace("sorted.bam", "pileup")
position = gene_dt["chromosome"] + ":" + str(gene_dt["start"]) + "-" + str(gene_dt["end"])

cmd = "samtools mpileup -f %s -r %s -Q 0 -aa -B %s > %s" % (gene_dt["genome"], 
                                                            position, 
                                                            pileup_bam, 
                                                            pileup_path)
print("Generating pileup...")
print(cmd)
os.system(cmd)
print("Done.")
# Out:
# Generating pileup...
# samtools mpileup -f data/resources/plasmodb/39/PlasmoDB-39_Pfalciparum3D7_Genome.fasta -r Pf3D7_13_v3:1724817-1726997 -Q 0 -aa -B data/ont/uk/2019-03-28/BC08.sorted.bam > data/ont/uk/2019-03-28/BC08.pileup
# Done.

# %%
# Make necessary prepartions if the gene is on the reverse strand
if gene_dt['strand'] == 'reverse':
    print("Gene is on reverse strand, inverting pileup.")
    print("Note: still need to perform reverse complementation.")
    pileup_path_reverse = pileup_path.replace("pileup", "reverse.pileup")
    os.system('tail -r %s > %s' % (pileup_path, pileup_path_reverse))
    pileup_path = pileup_path_reverse
else:
    print("Gene is on forward strand.")
# Out:
# Gene is on reverse strand, inverting pileup.
# Note: still need to perform reverse complementation.

# %%
# Search for mutations
mutation_dt = {
    "position": [],
    "total_counts": [],
    "total_counts_noindel": [],
    "ref_codon": [],
    "ref_amino": [],
    "ref_freq": [],
    "major_codon": [],
    "major_amino": [],
    "major_freq": [],
    "n_mutation_types": [],
    "mutation_codon": [],
    "mutation_amino": [],
    "mutation_freq": [],
}

# %%
with open(pileup_path, "r") as fn:
    
    # want to loop until you have a full codon
    nts = 0
    codon_position = 0
    codon_ref_nts = []
    codon_pileup = []
    for i, line in enumerate(fn):
        nts += 1
        chrom, pos, ref, coverage, pileup, _ = line.split("\t")
        processed_pileup = process_pileup(pileup, ref)
        if gene_dt["strand"] == 'reverse':
            ref = complement_map[ref]
            processed_pileup = "".join([complement_map[base] for base in processed_pileup])
        codon_ref_nts.append(ref)
        codon_pileup.append(processed_pileup)

        if nts == 3:
            codon_position += 1
            print("--------------------------------------------------------------------------------")
            print("Checking Codon:", codon_position)
            # Search the codon for non-synonymous mutations above a specified frequency
            assert len(codon_ref_nts) == 3
            assert len(codon_pileup) == 3
            
            # Pre-process from lists into strings
            codon_ref = "".join(codon_ref_nts)
            amino_ref = codon_to_amino(codon_ref, genetic_code)
            codon_pileup = ["".join(c) for c in zip(*codon_pileup)]
            
            # Get frequencies of codons (i.e. nucleotide level)
            codon_frequencies = Counter(codon_pileup)
            major_codon, major_codon_count = codon_frequencies.most_common(1)[0]
            ref_codon_count = codon_frequencies[codon_ref]
            total_codon_count = sum(codon_frequencies.values())

            print("Discovered...")
            print("  Total codon count (including indels):", total_codon_count)
            print("  Reference codon (from 3D7):", codon_ref)
            print("  Reference codon count:", ref_codon_count)
            print("  Majority codon (from pileup):", major_codon)
            print("  Majority codon count:", major_codon_count)
            print("  Number of unique codons discovered (including indels):", len(codon_frequencies))
            print("")

            # Restrict to codon observations without indels
            # - these can be used to look for non-synonymous changes
            codon_noindel_frequencies = Counter(dict([(c, v) for c, v in codon_frequencies.items() 
                                                      if not "+" in c and not "-" in c]))
            total_noindel_count = sum(codon_noindel_frequencies.values())

            # Now get non-synonymous frequencies
            codon_nonsyn_frequencies = Counter(dict([(c, v) for c, v in codon_noindel_frequencies.items()
                                                     if codon_to_amino(c, genetic_code) != amino_ref]))
            
            
            
            
            print("  Total codon count (excluding indels):", total_noindel_count)
            print("    Unique types:", len(codon_noindel_frequencies))
            print("    Non-synonymous:", len(codon_nonsyn_frequencies))
            print("")
            if len(codon_nonsyn_frequencies) > 0:
                highest_nonsyn_codon, highest_nonsyn_count = codon_nonsyn_frequencies.most_common(1)[0]
                print("    Highest frequency non-synonymous: %s = %s" 
                      % (highest_nonsyn_codon, codon_to_amino(highest_nonsyn_codon, genetic_code)))
                print("                        at frequency: %.05f" 
                      % (highest_nonsyn_count/total_noindel_count))
                
                # Finally, check if any of the non-synonymous mutations are above
                # set threshold
                above = Counter(dict([(c, v) for c, v in codon_nonsyn_frequencies.items() 
                      if v/total_noindel_count > min_freq]))
                if len(above) > 0:
                    n_above = len(above)
                    print("Detected %d non-synonymous mutations above frequency threshold of %.02f."
                          % (n_above, min_freq))
                    print("Storing results.")
                    
                    for mut_codon, mut_counts in above.items():
                        mutation_dt["position"].append(codon_position)
                        mutation_dt["total_counts"].append(total_codon_count)
                        mutation_dt["total_counts_noindel"].append(total_noindel_count)
                        
                        mutation_dt["ref_codon"].append(codon_ref)
                        mutation_dt["ref_amino"].append(amino_ref)
                        mutation_dt["ref_freq"].append(ref_codon_count/total_codon_count)
                        
                        mutation_dt["major_codon"].append(major_codon)
                        mutation_dt["major_amino"].append(codon_to_amino(major_codon, genetic_code))
                        mutation_dt["major_freq"].append(major_codon_count/total_noindel_count)
                        
                        mutation_dt["n_mutation_types"].append(len(codon_nonsyn_frequencies))
                        mutation_dt["mutation_codon"].append(mut_codon)
                        mutation_dt["mutation_amino"].append(codon_to_amino(mut_codon, genetic_code))
                        mutation_dt["mutation_freq"].append(mut_counts/total_noindel_count)

            else:
                print("    No non-synonymous mutations discovered.")
            print("")
            
            # Once mutation search is complete, reset codon and continue
            nts = 0
            codon_ref_nts = []
            codon_pileup = []
# Out:
# --------------------------------------------------------------------------------
# Checking Codon: 1
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): ATG
#   Reference codon count: 291
#   Majority codon (from pileup): ATG
#   Majority codon count: 291
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 304
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACG = T
#                         at frequency: 0.00987
#
# --------------------------------------------------------------------------------
# Checking Codon: 2
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): GAA
#   Reference codon count: 308
#   Majority codon (from pileup): GAA
#   Majority codon count: 308
#   Number of unique codons discovered (including indels): 13
#
#   Total codon count (excluding indels): 312
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: GAT = D
#                         at frequency: 0.00321
#
# --------------------------------------------------------------------------------
# Checking Codon: 3
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): GGA
#   Reference codon count: 313
#   Majority codon (from pileup): GGA
#   Majority codon count: 313
#   Number of unique codons discovered (including indels): 8
#
#   Total codon count (excluding indels): 313
#     Unique types: 1
#     Non-synonymous: 0
#
#     No non-synonymous mutations discovered.
#
# --------------------------------------------------------------------------------
# Checking Codon: 4
# Discovered...
#   Total codon count (including indels): 386
#   Reference codon (from 3D7): GAA
#   Reference codon count: 258
#   Majority codon (from pileup): GAA
#   Majority codon count: 258
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 276
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GCA = A
#                         at frequency: 0.01449
#
# --------------------------------------------------------------------------------
# Checking Codon: 5
# Discovered...
#   Total codon count (including indels): 377
#   Reference codon (from 3D7): AAA
#   Reference codon count: 146
#   Majority codon (from pileup): AA-
#   Majority codon count: 151
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 152
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: AGA = R
#                         at frequency: 0.01974
#
# --------------------------------------------------------------------------------
# Checking Codon: 6
# Discovered...
#   Total codon count (including indels): 380
#   Reference codon (from 3D7): GTA
#   Reference codon count: 179
#   Majority codon (from pileup): GTA
#   Majority codon count: 179
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 194
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: GCA = A
#                         at frequency: 0.03093
#
# --------------------------------------------------------------------------------
# Checking Codon: 7
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAA
#   Reference codon count: 322
#   Majority codon (from pileup): AAA
#   Majority codon count: 322
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 331
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAA = E
#                         at frequency: 0.00906
#
# --------------------------------------------------------------------------------
# Checking Codon: 8
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): ACA
#   Reference codon count: 133
#   Majority codon (from pileup): ACA
#   Majority codon count: 133
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 167
#     Unique types: 10
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: CCA = P
#                         at frequency: 0.06587
#
# --------------------------------------------------------------------------------
# Checking Codon: 9
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAA
#   Reference codon count: 290
#   Majority codon (from pileup): AAA
#   Majority codon count: 290
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 299
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.00669
#
# --------------------------------------------------------------------------------
# Checking Codon: 10
# Discovered...
#   Total codon count (including indels): 383
#   Reference codon (from 3D7): GCA
#   Reference codon count: 237
#   Majority codon (from pileup): GCA
#   Majority codon count: 237
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 256
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: ACA = T
#                         at frequency: 0.03125
#
# --------------------------------------------------------------------------------
# Checking Codon: 11
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAT
#   Reference codon count: 278
#   Majority codon (from pileup): AAT
#   Majority codon count: 278
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 295
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.01017
#
# --------------------------------------------------------------------------------
# Checking Codon: 12
# Discovered...
#   Total codon count (including indels): 377
#   Reference codon (from 3D7): AGT
#   Reference codon count: 277
#   Majority codon (from pileup): AGT
#   Majority codon count: 277
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 309
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.04207
#
# --------------------------------------------------------------------------------
# Checking Codon: 13
# Discovered...
#   Total codon count (including indels): 381
#   Reference codon (from 3D7): ATC
#   Reference codon count: 297
#   Majority codon (from pileup): ATC
#   Majority codon count: 297
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 307
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: GTC = V
#                         at frequency: 0.00977
#
# --------------------------------------------------------------------------------
# Checking Codon: 14
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): TCG
#   Reference codon count: 202
#   Majority codon (from pileup): TCG
#   Majority codon count: 202
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 230
#     Unique types: 10
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: TTG = L
#                         at frequency: 0.00870
#
# --------------------------------------------------------------------------------
# Checking Codon: 15
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AAT
#   Reference codon count: 237
#   Majority codon (from pileup): AAT
#   Majority codon count: 237
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 279
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GAT = D
#                         at frequency: 0.05376
#
# --------------------------------------------------------------------------------
# Checking Codon: 16
# Discovered...
#   Total codon count (including indels): 369
#   Reference codon (from 3D7): TTT
#   Reference codon count: 306
#   Majority codon (from pileup): TTT
#   Majority codon count: 306
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 325
#     Unique types: 10
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: CTT = L
#                         at frequency: 0.01846
#
# --------------------------------------------------------------------------------
# Checking Codon: 17
# Discovered...
#   Total codon count (including indels): 369
#   Reference codon (from 3D7): TCT
#   Reference codon count: 150
#   Majority codon (from pileup): TCT
#   Majority codon count: 150
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 164
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: CCT = P
#                         at frequency: 0.03049
#
# --------------------------------------------------------------------------------
# Checking Codon: 18
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): ATG
#   Reference codon count: 265
#   Majority codon (from pileup): ATG
#   Majority codon count: 265
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 277
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAG = K
#                         at frequency: 0.01444
#
# --------------------------------------------------------------------------------
# Checking Codon: 19
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): ACG
#   Reference codon count: 309
#   Majority codon (from pileup): ACG
#   Majority codon count: 309
#   Number of unique codons discovered (including indels): 13
#
#   Total codon count (excluding indels): 322
#     Unique types: 6
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: AGG = R
#                         at frequency: 0.00621
#
# --------------------------------------------------------------------------------
# Checking Codon: 20
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): TAT
#   Reference codon count: 271
#   Majority codon (from pileup): TAT
#   Majority codon count: 271
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 297
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: TAA = _
#                         at frequency: 0.02694
#
# --------------------------------------------------------------------------------
# Checking Codon: 21
# Discovered...
#   Total codon count (including indels): 370
#   Reference codon (from 3D7): GAT
#   Reference codon count: 309
#   Majority codon (from pileup): GAT
#   Majority codon count: 309
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 320
#     Unique types: 8
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GGT = G
#                         at frequency: 0.01250
#
# --------------------------------------------------------------------------------
# Checking Codon: 22
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AGG
#   Reference codon count: 240
#   Majority codon (from pileup): AGG
#   Majority codon count: 240
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 280
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: GGG = G
#                         at frequency: 0.02143
#
# --------------------------------------------------------------------------------
# Checking Codon: 23
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): GAA
#   Reference codon count: 149
#   Majority codon (from pileup): GAA
#   Majority codon count: 149
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 158
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: AAA = K
#                         at frequency: 0.03797
#
# --------------------------------------------------------------------------------
# Checking Codon: 24
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): TCT
#   Reference codon count: 297
#   Majority codon (from pileup): TCT
#   Majority codon count: 297
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 315
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TAT = Y
#                         at frequency: 0.00635
#
# --------------------------------------------------------------------------------
# Checking Codon: 25
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): GGT
#   Reference codon count: 205
#   Majority codon (from pileup): GGT
#   Majority codon count: 205
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 239
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AGT = S
#                         at frequency: 0.05021
#
# --------------------------------------------------------------------------------
# Checking Codon: 26
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): GGT
#   Reference codon count: 225
#   Majority codon (from pileup): GGT
#   Majority codon count: 225
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 240
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: AGT = S
#                         at frequency: 0.02083
#
# --------------------------------------------------------------------------------
# Checking Codon: 27
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): AAC
#   Reference codon count: 236
#   Majority codon (from pileup): AAC
#   Majority codon count: 236
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 266
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAA = K
#                         at frequency: 0.03008
#
# --------------------------------------------------------------------------------
# Checking Codon: 28
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AGC
#   Reference codon count: 241
#   Majority codon (from pileup): AGC
#   Majority codon count: 241
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 288
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAC = N
#                         at frequency: 0.06250
#
# --------------------------------------------------------------------------------
# Checking Codon: 29
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): AAT
#   Reference codon count: 285
#   Majority codon (from pileup): AAT
#   Majority codon count: 285
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 299
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.01003
#
# --------------------------------------------------------------------------------
# Checking Codon: 30
# Discovered...
#   Total codon count (including indels): 379
#   Reference codon (from 3D7): AGT
#   Reference codon count: 275
#   Majority codon (from pileup): AGT
#   Majority codon count: 275
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 302
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.01987
#
# --------------------------------------------------------------------------------
# Checking Codon: 31
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): GAT
#   Reference codon count: 304
#   Majority codon (from pileup): GAT
#   Majority codon count: 304
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 319
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.01254
#
# --------------------------------------------------------------------------------
# Checking Codon: 32
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): GAT
#   Reference codon count: 283
#   Majority codon (from pileup): GAT
#   Majority codon count: 283
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 295
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GTT = V
#                         at frequency: 0.01017
#
# --------------------------------------------------------------------------------
# Checking Codon: 33
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): AAA
#   Reference codon count: 282
#   Majority codon (from pileup): AAA
#   Majority codon count: 282
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 290
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: AAC = N
#                         at frequency: 0.00690
#
# --------------------------------------------------------------------------------
# Checking Codon: 34
# Discovered...
#   Total codon count (including indels): 369
#   Reference codon (from 3D7): AGC
#   Reference codon count: 171
#   Majority codon (from pileup): AGC
#   Majority codon count: 171
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 210
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: AAC = N
#                         at frequency: 0.01429
#
# --------------------------------------------------------------------------------
# Checking Codon: 35
# Discovered...
#   Total codon count (including indels): 380
#   Reference codon (from 3D7): GGA
#   Reference codon count: 169
#   Majority codon (from pileup): GGA
#   Majority codon count: 169
#   Number of unique codons discovered (including indels): 25
#
#   Total codon count (excluding indels): 186
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AGA = R
#                         at frequency: 0.03226
#
# --------------------------------------------------------------------------------
# Checking Codon: 36
# Discovered...
#   Total codon count (including indels): 384
#   Reference codon (from 3D7): AGT
#   Reference codon count: 269
#   Majority codon (from pileup): AGT
#   Majority codon count: 269
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 286
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: AGA = R
#                         at frequency: 0.01049
#
# --------------------------------------------------------------------------------
# Checking Codon: 37
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AGT
#   Reference codon count: 293
#   Majority codon (from pileup): AGT
#   Majority codon count: 293
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 326
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AGA = R
#                         at frequency: 0.04294
#
# --------------------------------------------------------------------------------
# Checking Codon: 38
# Discovered...
#   Total codon count (including indels): 376
#   Reference codon (from 3D7): AGC
#   Reference codon count: 246
#   Majority codon (from pileup): AGC
#   Majority codon count: 246
#   Number of unique codons discovered (including indels): 28
#
#   Total codon count (excluding indels): 279
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: ATC = I
#                         at frequency: 0.01792
#
# --------------------------------------------------------------------------------
# Checking Codon: 39
# Discovered...
#   Total codon count (including indels): 377
#   Reference codon (from 3D7): GAG
#   Reference codon count: 222
#   Majority codon (from pileup): GAG
#   Majority codon count: 222
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 232
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: GGG = G
#                         at frequency: 0.02155
#
# --------------------------------------------------------------------------------
# Checking Codon: 40
# Discovered...
#   Total codon count (including indels): 384
#   Reference codon (from 3D7): AAT
#   Reference codon count: 261
#   Majority codon (from pileup): AAT
#   Majority codon count: 261
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 280
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.01429
#
# --------------------------------------------------------------------------------
# Checking Codon: 41
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): GAT
#   Reference codon count: 281
#   Majority codon (from pileup): GAT
#   Majority codon count: 281
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 314
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.01274
#
# --------------------------------------------------------------------------------
# Checking Codon: 42
# Discovered...
#   Total codon count (including indels): 369
#   Reference codon (from 3D7): TCT
#   Reference codon count: 247
#   Majority codon (from pileup): TCT
#   Majority codon count: 247
#   Number of unique codons discovered (including indels): 12
#
#   Total codon count (excluding indels): 256
#     Unique types: 5
#     Non-synonymous: 2
#
#     Highest frequency non-synonymous: TTT = F
#                         at frequency: 0.01562
#
# --------------------------------------------------------------------------------
# Checking Codon: 43
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): AAT
#   Reference codon count: 290
#   Majority codon (from pileup): AAT
#   Majority codon count: 290
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 313
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: GAT = D
#                         at frequency: 0.02236
#
# --------------------------------------------------------------------------------
# Checking Codon: 44
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): TCA
#   Reference codon count: 294
#   Majority codon (from pileup): TCA
#   Majority codon count: 294
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 308
#     Unique types: 8
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: CCA = P
#                         at frequency: 0.00974
#
# --------------------------------------------------------------------------------
# Checking Codon: 45
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): TTT
#   Reference codon count: 307
#   Majority codon (from pileup): TTT
#   Majority codon count: 307
#   Number of unique codons discovered (including indels): 11
#
#   Total codon count (excluding indels): 313
#     Unique types: 4
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: TCT = S
#                         at frequency: 0.00639
#
# --------------------------------------------------------------------------------
# Checking Codon: 46
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): ATG
#   Reference codon count: 278
#   Majority codon (from pileup): ATG
#   Majority codon count: 278
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 296
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ATA = I
#                         at frequency: 0.02703
#
# --------------------------------------------------------------------------------
# Checking Codon: 47
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAT
#   Reference codon count: 306
#   Majority codon (from pileup): AAT
#   Majority codon count: 306
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 320
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAT = D
#                         at frequency: 0.01875
#
# --------------------------------------------------------------------------------
# Checking Codon: 48
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): CTA
#   Reference codon count: 296
#   Majority codon (from pileup): CTA
#   Majority codon count: 296
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 313
#     Unique types: 7
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: CCA = P
#                         at frequency: 0.01278
#
# --------------------------------------------------------------------------------
# Checking Codon: 49
# Discovered...
#   Total codon count (including indels): 368
#   Reference codon (from 3D7): ACT
#   Reference codon count: 288
#   Majority codon (from pileup): ACT
#   Majority codon count: 288
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 314
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: GCT = A
#                         at frequency: 0.02229
#
# --------------------------------------------------------------------------------
# Checking Codon: 50
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): AGT
#   Reference codon count: 280
#   Majority codon (from pileup): AGT
#   Majority codon count: 280
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 299
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.02007
#
# --------------------------------------------------------------------------------
# Checking Codon: 51
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): GAT
#   Reference codon count: 280
#   Majority codon (from pileup): GAT
#   Majority codon count: 280
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 302
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.01656
#
# --------------------------------------------------------------------------------
# Checking Codon: 52
# Discovered...
#   Total codon count (including indels): 369
#   Reference codon (from 3D7): AAA
#   Reference codon count: 320
#   Majority codon (from pileup): AAA
#   Majority codon count: 320
#   Number of unique codons discovered (including indels): 11
#
#   Total codon count (excluding indels): 330
#     Unique types: 5
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TAA = _
#                         at frequency: 0.01212
#
# --------------------------------------------------------------------------------
# Checking Codon: 53
# Discovered...
#   Total codon count (including indels): 368
#   Reference codon (from 3D7): AAT
#   Reference codon count: 97
#   Majority codon (from pileup): A-T
#   Majority codon count: 105
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 102
#     Unique types: 4
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: ATT = I
#                         at frequency: 0.02941
#
# --------------------------------------------------------------------------------
# Checking Codon: 54
# Discovered...
#   Total codon count (including indels): 376
#   Reference codon (from 3D7): GAG
#   Reference codon count: 256
#   Majority codon (from pileup): GAG
#   Majority codon count: 256
#   Number of unique codons discovered (including indels): 12
#
#   Total codon count (excluding indels): 263
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: GTG = V
#                         at frequency: 0.00380
#
# --------------------------------------------------------------------------------
# Checking Codon: 55
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAA
#   Reference codon count: 237
#   Majority codon (from pileup): AAA
#   Majority codon count: 237
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 245
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TAA = _
#                         at frequency: 0.00816
#
# --------------------------------------------------------------------------------
# Checking Codon: 56
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): ACG
#   Reference codon count: 218
#   Majority codon (from pileup): ACG
#   Majority codon count: 218
#   Number of unique codons discovered (including indels): 28
#
#   Total codon count (excluding indels): 238
#     Unique types: 9
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: TCG = S
#                         at frequency: 0.02101
#
# --------------------------------------------------------------------------------
# Checking Codon: 57
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): GAA
#   Reference codon count: 267
#   Majority codon (from pileup): GAA
#   Majority codon count: 267
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 282
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GGA = G
#                         at frequency: 0.01418
#
# --------------------------------------------------------------------------------
# Checking Codon: 58
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): AAT
#   Reference codon count: 243
#   Majority codon (from pileup): AAT
#   Majority codon count: 243
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 257
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AGT = S
#                         at frequency: 0.01167
#
# --------------------------------------------------------------------------------
# Checking Codon: 59
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): AAT
#   Reference codon count: 251
#   Majority codon (from pileup): AAT
#   Majority codon count: 251
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 270
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: ATT = I
#                         at frequency: 0.01852
#
# --------------------------------------------------------------------------------
# Checking Codon: 60
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): AGT
#   Reference codon count: 262
#   Majority codon (from pileup): AGT
#   Majority codon count: 262
#   Number of unique codons discovered (including indels): 23
#
#   Total codon count (excluding indels): 291
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: GGT = G
#                         at frequency: 0.03780
#
# --------------------------------------------------------------------------------
# Checking Codon: 61
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): TTC
#   Reference codon count: 264
#   Majority codon (from pileup): TTC
#   Majority codon count: 264
#   Number of unique codons discovered (including indels): 12
#
#   Total codon count (excluding indels): 271
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: CTC = L
#                         at frequency: 0.01476
#
# --------------------------------------------------------------------------------
# Checking Codon: 62
# Discovered...
#   Total codon count (including indels): 383
#   Reference codon (from 3D7): CTT
#   Reference codon count: 181
#   Majority codon (from pileup): CTT
#   Majority codon count: 181
#   Number of unique codons discovered (including indels): 22
#
#   Total codon count (excluding indels): 201
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: CCT = P
#                         at frequency: 0.03483
#
# --------------------------------------------------------------------------------
# Checking Codon: 63
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): TTA
#   Reference codon count: 194
#   Majority codon (from pileup): TTA
#   Majority codon count: 194
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 210
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: TCA = S
#                         at frequency: 0.01429
#
# --------------------------------------------------------------------------------
# Checking Codon: 64
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AAT
#   Reference codon count: 294
#   Majority codon (from pileup): AAT
#   Majority codon count: 294
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 322
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: AAG = K
#                         at frequency: 0.01863
#
# --------------------------------------------------------------------------------
# Checking Codon: 65
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AAT
#   Reference codon count: 314
#   Majority codon (from pileup): AAT
#   Majority codon count: 314
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 329
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: ATT = I
#                         at frequency: 0.01216
#
# --------------------------------------------------------------------------------
# Checking Codon: 66
# Discovered...
#   Total codon count (including indels): 377
#   Reference codon (from 3D7): AGT
#   Reference codon count: 276
#   Majority codon (from pileup): AGT
#   Majority codon count: 276
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 305
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.03279
#
# --------------------------------------------------------------------------------
# Checking Codon: 67
# Discovered...
#   Total codon count (including indels): 376
#   Reference codon (from 3D7): AGT
#   Reference codon count: 269
#   Majority codon (from pileup): AGT
#   Majority codon count: 269
#   Number of unique codons discovered (including indels): 22
#
#   Total codon count (excluding indels): 298
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.02013
#
# --------------------------------------------------------------------------------
# Checking Codon: 68
# Discovered...
#   Total codon count (including indels): 380
#   Reference codon (from 3D7): TAT
#   Reference codon count: 284
#   Majority codon (from pileup): TAT
#   Majority codon count: 284
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 302
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: TGT = C
#                         at frequency: 0.02649
#
# --------------------------------------------------------------------------------
# Checking Codon: 69
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): GGA
#   Reference codon count: 259
#   Majority codon (from pileup): GGA
#   Majority codon count: 259
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 276
#     Unique types: 8
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAA = E
#                         at frequency: 0.01812
#
# --------------------------------------------------------------------------------
# Checking Codon: 70
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAT
#   Reference codon count: 304
#   Majority codon (from pileup): AAT
#   Majority codon count: 304
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 316
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.01266
#
# --------------------------------------------------------------------------------
# Checking Codon: 71
# Discovered...
#   Total codon count (including indels): 377
#   Reference codon (from 3D7): GTT
#   Reference codon count: 282
#   Majority codon (from pileup): GTT
#   Majority codon count: 282
#   Number of unique codons discovered (including indels): 23
#
#   Total codon count (excluding indels): 306
#     Unique types: 10
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: ATT = I
#                         at frequency: 0.02288
#
# --------------------------------------------------------------------------------
# Checking Codon: 72
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAA
#   Reference codon count: 284
#   Majority codon (from pileup): AAA
#   Majority codon count: 284
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 297
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAA = E
#                         at frequency: 0.01347
#
# --------------------------------------------------------------------------------
# Checking Codon: 73
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): GAT
#   Reference codon count: 272
#   Majority codon (from pileup): GAT
#   Majority codon count: 272
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 292
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GAG = E
#                         at frequency: 0.01027
#
# --------------------------------------------------------------------------------
# Checking Codon: 74
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): AGC
#   Reference codon count: 268
#   Majority codon (from pileup): AGC
#   Majority codon count: 268
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 314
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: AAC = N
#                         at frequency: 0.06369
#
# --------------------------------------------------------------------------------
# Checking Codon: 75
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): CTA
#   Reference codon count: 244
#   Majority codon (from pileup): CTA
#   Majority codon count: 244
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 283
#     Unique types: 8
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: CCA = P
#                         at frequency: 0.03534
#
# --------------------------------------------------------------------------------
# Checking Codon: 76
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): TTA
#   Reference codon count: 267
#   Majority codon (from pileup): TTA
#   Majority codon count: 267
#   Number of unique codons discovered (including indels): 25
#
#   Total codon count (excluding indels): 296
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ATA = I
#                         at frequency: 0.04054
#
# --------------------------------------------------------------------------------
# Checking Codon: 77
# Discovered...
#   Total codon count (including indels): 379
#   Reference codon (from 3D7): GAA
#   Reference codon count: 270
#   Majority codon (from pileup): GAA
#   Majority codon count: 270
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 287
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: AAA = K
#                         at frequency: 0.02091
#
# --------------------------------------------------------------------------------
# Checking Codon: 78
# Discovered...
#   Total codon count (including indels): 370
#   Reference codon (from 3D7): TCC
#   Reference codon count: 188
#   Majority codon (from pileup): TCC
#   Majority codon count: 188
#   Number of unique codons discovered (including indels): 27
#
#   Total codon count (excluding indels): 221
#     Unique types: 8
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TTC = F
#                         at frequency: 0.02262
#
# --------------------------------------------------------------------------------
# Checking Codon: 79
# Discovered...
#   Total codon count (including indels): 372
#   Reference codon (from 3D7): ATT
#   Reference codon count: 273
#   Majority codon (from pileup): ATT
#   Majority codon count: 273
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 308
#     Unique types: 7
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.06494
#
# --------------------------------------------------------------------------------
# Checking Codon: 80
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): GAT
#   Reference codon count: 301
#   Majority codon (from pileup): GAT
#   Majority codon count: 301
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 312
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GTT = V
#                         at frequency: 0.00641
#
# --------------------------------------------------------------------------------
# Checking Codon: 81
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): ATG
#   Reference codon count: 229
#   Majority codon (from pileup): ATG
#   Majority codon count: 229
#   Number of unique codons discovered (including indels): 22
#
#   Total codon count (excluding indels): 256
#     Unique types: 8
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AAG = K
#                         at frequency: 0.05078
#
# --------------------------------------------------------------------------------
# Checking Codon: 82
# Discovered...
#   Total codon count (including indels): 379
#   Reference codon (from 3D7): AGT
#   Reference codon count: 225
#   Majority codon (from pileup): AGT
#   Majority codon count: 225
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 246
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: GGT = G
#                         at frequency: 0.02846
#
# --------------------------------------------------------------------------------
# Checking Codon: 83
# Discovered...
#   Total codon count (including indels): 376
#   Reference codon (from 3D7): GTA
#   Reference codon count: 246
#   Majority codon (from pileup): GTA
#   Majority codon count: 246
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 270
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: GGA = G
#                         at frequency: 0.01481
#
# --------------------------------------------------------------------------------
# Checking Codon: 84
# Discovered...
#   Total codon count (including indels): 375
#   Reference codon (from 3D7): TTA
#   Reference codon count: 254
#   Majority codon (from pileup): TTA
#   Majority codon count: 254
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 280
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ATA = I
#                         at frequency: 0.03571
#
# --------------------------------------------------------------------------------
# Checking Codon: 85
# Discovered...
#   Total codon count (including indels): 371
#   Reference codon (from 3D7): GAT
#   Reference codon count: 265
#   Majority codon (from pileup): GAT
#   Majority codon count: 265
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 287
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.02091
#
# --------------------------------------------------------------------------------
# Checking Codon: 86
# Discovered...
#   Total codon count (including indels): 378
#   Reference codon (from 3D7): TCG
#   Reference codon count: 250
#   Majority codon (from pileup): TCG
#   Majority codon count: 250
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 279
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: CTG = L
#                         at frequency: 0.03226
#
# --------------------------------------------------------------------------------
# Checking Codon: 87
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): AAC
#   Reference codon count: 290
#   Majority codon (from pileup): AAC
#   Majority codon count: 290
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 311
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAC = D
#                         at frequency: 0.02894
#
# --------------------------------------------------------------------------------
# Checking Codon: 88
# Discovered...
#   Total codon count (including indels): 370
#   Reference codon (from 3D7): TTT
#   Reference codon count: 257
#   Majority codon (from pileup): TTT
#   Majority codon count: 257
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 273
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: TTG = L
#                         at frequency: 0.01465
#
# --------------------------------------------------------------------------------
# Checking Codon: 89
# Discovered...
#   Total codon count (including indels): 373
#   Reference codon (from 3D7): GAT
#   Reference codon count: 251
#   Majority codon (from pileup): GAT
#   Majority codon count: 251
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 266
#     Unique types: 9
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: GTT = V
#                         at frequency: 0.01128
#
# --------------------------------------------------------------------------------
# Checking Codon: 90
# Discovered...
#   Total codon count (including indels): 376
#   Reference codon (from 3D7): AGT
#   Reference codon count: 267
#   Majority codon (from pileup): AGT
#   Majority codon count: 267
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 297
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.03030
#
# --------------------------------------------------------------------------------
# Checking Codon: 91
# Discovered...
#   Total codon count (including indels): 374
#   Reference codon (from 3D7): AAA
#   Reference codon count: 306
#   Majority codon (from pileup): AAA
#   Majority codon count: 306
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 315
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GAA = E
#                         at frequency: 0.00317
#
# --------------------------------------------------------------------------------
# Checking Codon: 92
# Discovered...
#   Total codon count (including indels): 370
# ...
#
# --------------------------------------------------------------------------------
# Checking Codon: 698
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): TTC
#   Reference codon count: 245
#   Majority codon (from pileup): TTC
#   Majority codon count: 245
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 258
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: TAC = Y
#                         at frequency: 0.01938
#
# --------------------------------------------------------------------------------
# Checking Codon: 699
# Discovered...
#   Total codon count (including indels): 353
#   Reference codon (from 3D7): TTT
#   Reference codon count: 222
#   Majority codon (from pileup): TTT
#   Majority codon count: 222
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 232
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: TGT = C
#                         at frequency: 0.01293
#
# --------------------------------------------------------------------------------
# Checking Codon: 700
# Discovered...
#   Total codon count (including indels): 357
#   Reference codon (from 3D7): TCA
#   Reference codon count: 159
#   Majority codon (from pileup): TCA
#   Majority codon count: 159
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 171
#     Unique types: 4
#     Non-synonymous: 1
#
#     Highest frequency non-synonymous: CCA = P
#                         at frequency: 0.00585
#
# --------------------------------------------------------------------------------
# Checking Codon: 701
# Discovered...
#   Total codon count (including indels): 352
#   Reference codon (from 3D7): CCA
#   Reference codon count: 218
#   Majority codon (from pileup): CCA
#   Majority codon count: 218
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 261
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: CTA = L
#                         at frequency: 0.06130
#
# --------------------------------------------------------------------------------
# Checking Codon: 702
# Discovered...
#   Total codon count (including indels): 352
#   Reference codon (from 3D7): GAT
#   Reference codon count: 290
#   Majority codon (from pileup): GAT
#   Majority codon count: 290
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 307
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: AAT = N
#                         at frequency: 0.01303
#
# --------------------------------------------------------------------------------
# Checking Codon: 703
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): ACA
#   Reference codon count: 270
#   Majority codon (from pileup): ACA
#   Majority codon count: 270
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 284
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: GCA = A
#                         at frequency: 0.01761
#
# --------------------------------------------------------------------------------
# Checking Codon: 704
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): AAT
#   Reference codon count: 249
#   Majority codon (from pileup): AAT
#   Majority codon count: 249
#   Number of unique codons discovered (including indels): 10
#
#   Total codon count (excluding indels): 252
#     Unique types: 3
#     Non-synonymous: 1
#
#     Highest frequency non-synonymous: GGT = G
#                         at frequency: 0.00397
#
# --------------------------------------------------------------------------------
# Checking Codon: 705
# Discovered...
#   Total codon count (including indels): 350
#   Reference codon (from 3D7): GAA
#   Reference codon count: 288
#   Majority codon (from pileup): GAA
#   Majority codon count: 288
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 300
#     Unique types: 6
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: GGA = G
#                         at frequency: 0.01667
#
# --------------------------------------------------------------------------------
# Checking Codon: 706
# Discovered...
#   Total codon count (including indels): 355
#   Reference codon (from 3D7): TGG
#   Reference codon count: 272
#   Majority codon (from pileup): TGG
#   Majority codon count: 272
#   Number of unique codons discovered (including indels): 21
#
#   Total codon count (excluding indels): 296
#     Unique types: 10
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: TAG = _
#                         at frequency: 0.04730
#
# --------------------------------------------------------------------------------
# Checking Codon: 707
# Discovered...
#   Total codon count (including indels): 356
#   Reference codon (from 3D7): CAG
#   Reference codon count: 246
#   Majority codon (from pileup): CAG
#   Majority codon count: 246
#   Number of unique codons discovered (including indels): 22
#
#   Total codon count (excluding indels): 289
#     Unique types: 11
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: TAG = _
#                         at frequency: 0.01384
#
# --------------------------------------------------------------------------------
# Checking Codon: 708
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): CTT
#   Reference codon count: 194
#   Majority codon (from pileup): CTT
#   Majority codon count: 194
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 239
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TTT = F
#                         at frequency: 0.10879
# Detected 1 non-synonymous mutations above frequency threshold of 0.10.
# Storing results.
#
# --------------------------------------------------------------------------------
# Checking Codon: 709
# Discovered...
#   Total codon count (including indels): 367
#   Reference codon (from 3D7): GGC
#   Reference codon count: 187
#   Majority codon (from pileup): GGC
#   Majority codon count: 187
#   Number of unique codons discovered (including indels): 33
#
#   Total codon count (excluding indels): 228
#     Unique types: 14
#     Non-synonymous: 11
#
#     Highest frequency non-synonymous: AGC = S
#                         at frequency: 0.07895
#
# --------------------------------------------------------------------------------
# Checking Codon: 710
# Discovered...
#   Total codon count (including indels): 362
#   Reference codon (from 3D7): CCA
#   Reference codon count: 229
#   Majority codon (from pileup): CCA
#   Majority codon count: 229
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 259
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TCA = S
#                         at frequency: 0.05019
#
# --------------------------------------------------------------------------------
# Checking Codon: 711
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): TCT
#   Reference codon count: 308
#   Majority codon (from pileup): TCT
#   Majority codon count: 308
#   Number of unique codons discovered (including indels): 12
#
#   Total codon count (excluding indels): 317
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: TGT = C
#                         at frequency: 0.00946
#
# --------------------------------------------------------------------------------
# Checking Codon: 712
# Discovered...
#   Total codon count (including indels): 347
#   Reference codon (from 3D7): TTA
#   Reference codon count: 211
#   Majority codon (from pileup): TTA
#   Majority codon count: 211
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 228
#     Unique types: 7
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TCA = S
#                         at frequency: 0.02193
#
# --------------------------------------------------------------------------------
# Checking Codon: 713
# Discovered...
#   Total codon count (including indels): 351
#   Reference codon (from 3D7): TTA
#   Reference codon count: 267
#   Majority codon (from pileup): TTA
#   Majority codon count: 267
#   Number of unique codons discovered (including indels): 20
#
#   Total codon count (excluding indels): 281
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ATA = I
#                         at frequency: 0.01423
#
# --------------------------------------------------------------------------------
# Checking Codon: 714
# Discovered...
#   Total codon count (including indels): 351
#   Reference codon (from 3D7): GTT
#   Reference codon count: 293
#   Majority codon (from pileup): GTT
#   Majority codon count: 293
#   Number of unique codons discovered (including indels): 12
#
#   Total codon count (excluding indels): 306
#     Unique types: 5
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: GCT = A
#                         at frequency: 0.01634
#
# --------------------------------------------------------------------------------
# Checking Codon: 715
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): CCC
#   Reference codon count: 178
#   Majority codon (from pileup): CCC
#   Majority codon count: 178
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 256
#     Unique types: 13
#     Non-synonymous: 9
#
#     Highest frequency non-synonymous: CTC = L
#                         at frequency: 0.13672
# Detected 1 non-synonymous mutations above frequency threshold of 0.10.
# Storing results.
#
# --------------------------------------------------------------------------------
# Checking Codon: 716
# Discovered...
#   Total codon count (including indels): 359
#   Reference codon (from 3D7): AGA
#   Reference codon count: 232
#   Majority codon (from pileup): AGA
#   Majority codon count: 232
#   Number of unique codons discovered (including indels): 17
#
#   Total codon count (excluding indels): 246
#     Unique types: 6
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: TGA = _
#                         at frequency: 0.02033
#
# --------------------------------------------------------------------------------
# Checking Codon: 717
# Discovered...
#   Total codon count (including indels): 350
#   Reference codon (from 3D7): TTT
#   Reference codon count: 283
#   Majority codon (from pileup): TTT
#   Majority codon count: 283
#   Number of unique codons discovered (including indels): 16
#
#   Total codon count (excluding indels): 301
#     Unique types: 7
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: CTT = L
#                         at frequency: 0.01993
#
# --------------------------------------------------------------------------------
# Checking Codon: 718
# Discovered...
#   Total codon count (including indels): 359
#   Reference codon (from 3D7): GGT
#   Reference codon count: 212
#   Majority codon (from pileup): GGT
#   Majority codon count: 212
#   Number of unique codons discovered (including indels): 23
#
#   Total codon count (excluding indels): 242
#     Unique types: 10
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: AGT = S
#                         at frequency: 0.07851
#
# --------------------------------------------------------------------------------
# Checking Codon: 719
# Discovered...
#   Total codon count (including indels): 354
#   Reference codon (from 3D7): CAC
#   Reference codon count: 201
#   Majority codon (from pileup): CAC
#   Majority codon count: 201
#   Number of unique codons discovered (including indels): 19
#
#   Total codon count (excluding indels): 220
#     Unique types: 8
#     Non-synonymous: 7
#
#     Highest frequency non-synonymous: CAA = Q
#                         at frequency: 0.04091
#
# --------------------------------------------------------------------------------
# Checking Codon: 720
# Discovered...
#   Total codon count (including indels): 353
#   Reference codon (from 3D7): TCC
#   Reference codon count: 78
#   Majority codon (from pileup): TCC
#   Majority codon count: 78
#   Number of unique codons discovered (including indels): 23
#
#   Total codon count (excluding indels): 139
#     Unique types: 8
#     Non-synonymous: 5
#
#     Highest frequency non-synonymous: TTC = F
#                         at frequency: 0.03597
#
# --------------------------------------------------------------------------------
# Checking Codon: 721
# Discovered...
#   Total codon count (including indels): 350
#   Reference codon (from 3D7): GTT
#   Reference codon count: 256
#   Majority codon (from pileup): GTT
#   Majority codon count: 256
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 278
#     Unique types: 10
#     Non-synonymous: 8
#
#     Highest frequency non-synonymous: ATT = I
#                         at frequency: 0.02878
#
# --------------------------------------------------------------------------------
# Checking Codon: 722
# Discovered...
#   Total codon count (including indels): 351
#   Reference codon (from 3D7): TTA
#   Reference codon count: 215
#   Majority codon (from pileup): TTA
#   Majority codon count: 215
#   Number of unique codons discovered (including indels): 18
#
#   Total codon count (excluding indels): 223
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: GCA = A
#                         at frequency: 0.00897
#
# --------------------------------------------------------------------------------
# Checking Codon: 723
# Discovered...
#   Total codon count (including indels): 352
#   Reference codon (from 3D7): ATA
#   Reference codon count: 281
#   Majority codon (from pileup): ATA
#   Majority codon count: 281
#   Number of unique codons discovered (including indels): 13
#
#   Total codon count (excluding indels): 301
#     Unique types: 6
#     Non-synonymous: 4
#
#     Highest frequency non-synonymous: TTA = L
#                         at frequency: 0.02990
#
# --------------------------------------------------------------------------------
# Checking Codon: 724
# Discovered...
#   Total codon count (including indels): 359
#   Reference codon (from 3D7): GCA
#   Reference codon count: 223
#   Majority codon (from pileup): GCA
#   Majority codon count: 223
#   Number of unique codons discovered (including indels): 24
#
#   Total codon count (excluding indels): 274
#     Unique types: 9
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACA = T
#                         at frequency: 0.08029
#
# --------------------------------------------------------------------------------
# Checking Codon: 725
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): AAT
#   Reference codon count: 289
#   Majority codon (from pileup): AAT
#   Majority codon count: 289
#   Number of unique codons discovered (including indels): 15
#
#   Total codon count (excluding indels): 301
#     Unique types: 8
#     Non-synonymous: 6
#
#     Highest frequency non-synonymous: ACT = T
#                         at frequency: 0.01661
#
# --------------------------------------------------------------------------------
# Checking Codon: 726
# Discovered...
#   Total codon count (including indels): 349
#   Reference codon (from 3D7): ATA
#   Reference codon count: 306
#   Majority codon (from pileup): ATA
#   Majority codon count: 306
#   Number of unique codons discovered (including indels): 9
#
#   Total codon count (excluding indels): 319
#     Unique types: 6
#     Non-synonymous: 3
#
#     Highest frequency non-synonymous: ATG = M
#                         at frequency: 0.01254
#
# --------------------------------------------------------------------------------
# Checking Codon: 727
# Discovered...
#   Total codon count (including indels): 351
#   Reference codon (from 3D7): TAA
#   Reference codon count: 227
#   Majority codon (from pileup): TAA
#   Majority codon count: 227
#   Number of unique codons discovered (including indels): 14
#
#   Total codon count (excluding indels): 234
#     Unique types: 5
#     Non-synonymous: 2
#
#     Highest frequency non-synonymous: CAA = Q
#                         at frequency: 0.00855

# %%
def process_pileup(pileup, ref):
    """
    Process a read pileup from
    `samtools mpileup` into
    A,T,C,G,+,-
    
    Note, the solution is ugly, but
    re.sub([-+][0-9]+[ATCGatcg]+, ... fails when a variant
    follows directly after an indel.
    
    params
        pileup: str
            String giving all nucleotides mapped to a specific
            position, with characters defined by 
            `samtools mpileup`.
        ref: str
            String giving the reference base at this position.
    returns
        pileup:
            String with length <= pileup. Characters given in
            `samtools mpileup` are converted to the appropriate
            A, T, C, and G values. Insertions are represented
            by a single '+', deletions by a single '-'.
    """
    # indels are initiated with [+-][0-9]+[ATCGatcg]
    for indel_size in set(re.findall("\d+", pileup)):
        indel_size = int(indel_size)
        pileup = re.sub(r"[+-]%d[ATCGatcg]{%d}" % (indel_size, indel_size), "-", pileup)
   
    pileup = re.sub("\*", "-", pileup)  
    pileup = re.sub("\$|\^.", "", pileup)
    pileup = re.sub("\.|,", ref, pileup)
    pileup = pileup.upper()
    return pileup

# %%
mutation_df = pd.DataFrame(mutation_dt)
columns = ["position", "total_counts", "total_counts_noindel", 
           "ref_codon", "ref_amino", "ref_freq",
           "major_codon", "major_amino", "major_freq",
           "n_mutation_types",
           "mutation_codon", "mutation_amino", "mutation_freq"]
mutation_df = mutation_df[columns]
print("--------------------------------------------------------------------------------")
print("Mutation scan complete.")
print("================================================================================")
# Out:
# --------------------------------------------------------------------------------
# Mutation scan complete.
# ================================================================================

# %%
mutation_df
# Out:
#    position  total_counts  total_counts_noindel ref_codon ref_amino  ref_freq  \
# 0       189           354                   193       AAA         K  0.141243
# 1       189           354                   193       AAA         K  0.141243
# 2       413           351                   206       CCG         P  0.384615
# 3       553           347                   274       CCG         P  0.628242
# 4       603           352                   267       GTA         V  0.656250
# 5       708           349                   239       CTT         L  0.555874
# 6       715           349                   256       CCC         P  0.510029
#
#   major_codon major_amino  major_freq  n_mutation_types mutation_codon  \
# 0         ACA           T    0.424870                15            ACA
# 1         ACA           T    0.424870                15            CAA
# 2         CCG           P    0.655340                10            CTG
# 3         CCG           P    0.795620                 7            CTG
# 4         GTA           V    0.865169                 3            GCA
# 5         CTT           L    0.811715                 4            TTT
# 6         CCC           P    0.695312                 9            CTC
#
#   mutation_amino  mutation_freq
# 0              T       0.424870
# 1              Q       0.196891
# 2              L       0.131068
# 3              L       0.105839
# 4              A       0.108614
# 5              F       0.108787
# 6              L       0.136719
